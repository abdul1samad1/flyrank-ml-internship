# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdul1samad1/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Selected Lane: Lane 1 – Content Refresh & Decay Prediction
#
# Why this one? Search traffic for existing web pages naturally decays over time due to outdated information, shifting search intent, or competitor activity. Instead of waiting for organic traffic to collapse completely, predicting decay early allows teams to prioritize content refreshes proactively and protect revenue-generating search rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Search Question: Which high-visibility pages are undergoing systemic traffic decline and require immediate editorial refreshes?
#
# Unit of Analysis: A single page (URL) on a client domain.
#
# Decision: Flagging top-ranked, high-risk pages for manual human review versus leaving stable or growing pages unflagged.
#
# Who Acts On It? Content Strategists, SEO Specialists, and Editorial Teams.
#
# Cost of a Wrong Call:
#
# False Positive (Flagging a healthy page): Wasted editorial budget and staff hours spent re-optimizing content that didn't actually need updates.
# False Negative (Missing a decaying page): Sustained loss of organic search traffic, permanent drops in search rankings to competitors, and lost conversion opportunities over time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# **Supporting Metrics from Dataset:**
#
# 1. **Total Content Items (`dim_content`):** The dataset tracks **519,606** individual URLs across client domains, giving a large dataset to train decay prediction models.
# 2. **Client Scope (`dim_clients`):** Covers **104** distinct client domains, ensuring the model learns patterns across different industries.
# 3. **Daily Performance Granularity (`fact_daily_sample`):** Tracks daily impressions, clicks, and positions to capture traffic decline trends over time.

# %%
import duckdb

HF_TOKEN = "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"

con = duckdb.connect()
con.execute(
    f"CREATE OR REPLACE SECRET hf (TYPE huggingface, TOKEN '{HF_TOKEN}')"
)

REL = "hf://datasets/FlyRank/internship-warehouse"
TABLES = {
    "dim_clients": f"read_parquet('{REL}/dim_clients.parquet')",
    "dim_content": f"read_parquet('{REL}/dim_content.parquet')",
}

for name, src in TABLES.items():
    n = con.sql(f"SELECT COUNT(*) FROM {src}").fetchone()[0]
    print(f"{name:22} {n:>12,} rows")
# Out:
# dim_clients                     104 rows
# dim_content                 519,606 rows

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I CAN claim:**
# * I can identify observed patterns of organic traffic decay based on historical performance indicators.
# * I can provide directional risk scores to help editorial teams prioritize which pages to review first.
# * I can deliver decision-support flags that highlight pages experiencing statistically significant drops in impressions or clicks.
#
# **What I CANNOT claim:**
# * I cannot claim causal proof (e.g., proving Google penalized a page vs. a competitor publishing better content).
# * I cannot "predict Google's algorithm" or guarantee search ranking positions.
# * I cannot replace human editorial judgment; the output serves strictly as a prioritization queue for human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
